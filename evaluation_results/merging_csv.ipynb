# %%
import pandas as pd

# %%
prefix = 'evaluation_ftmodel_'
tl = ['all', 'chi', 'dan', 'eng', 'rom', 'slk']
df_list = []

for lang in tl:
    df = pd.read_csv(prefix + lang + '.csv')
    df['targ_lang'] = lang
    df = df.rename({'lang' : 'test_lang'}, axis= 1)
    df_list.append(df)

df_merged = pd.concat(df_list, axis= 0)
df_merged

def grouper(row):
    if row['test_lang'] in ['eng', 'ger', 'dan', 'nor', 'swe']:
        return 1
    elif row['test_lang'] in ['slk', 'srb', 'hrv']:
        return 2
    elif row['test_lang'] in ['rom', 'por']:
        return 3
    elif row['test_lang'] == 'heb':
        return 4
    elif row['test_lang'] == 'chi':
        return 5
    raise WindowsError("fuck YOU")

df_merged['group'] = df_merged.apply(grouper, axis= 1)
df_merged
# Out:
#     test_lang  epoch     F1  precision  recall  accuracy targ_lang  group
# 0         slk      1  0.830      0.806   0.856     0.975       all      2
# 1         slk      2  0.832      0.791   0.876     0.973       all      2
# 2         slk      3  0.807      0.762   0.858     0.973       all      2
# 3         slk      4  0.809      0.793   0.826     0.974       all      2
# 4         slk      5  0.811      0.783   0.842     0.974       all      2
# ..        ...    ...    ...        ...     ...       ...       ...    ...
# 235       dan     16  0.840      0.843   0.836     0.988       slk      1
# 236       dan     17  0.842      0.846   0.839     0.988       slk      1
# 237       dan     18  0.843      0.840   0.847     0.988       slk      1
# 238       dan     19  0.827      0.828   0.826     0.987       slk      1
# 239       dan     20  0.836      0.836   0.836     0.988       slk      1
#
# [1440 rows x 8 columns]

# %%
df_merged.to_csv("evaluation_merged.csv", index= False)
